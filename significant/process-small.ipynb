# %%
import os
import json
import statistics as st
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
def clean(data):
    for k1 in data.keys():
        for k2 in data[k1].keys():
            se = stats.sem([float(x) for x in data[k1][k2]])
            print(f'''Std Err: {k1}, {k2}, {se}''')
            data[k1][k2] = round(st.mean([float(x) for x in data[k1][k2]]), 4)
    return data

# %%
def add_values():
    vals = {}
    kstrings = []
    target = 'new_results'
    dirs = sorted(os.listdir(os.path.join(os.getcwd(), target)))
    for file in dirs:
#         print(file)
        if file == '.DS_Store':
            continue
#         f = open(os.path.join(target, file), 'r')
#         data = json.load(f)
#         f.close()
        filez = file.split(':')
        n = ''.join([x for x in filez[2] if x.isdigit()])
        m = ''.join([x for x in filez[3] if x.isdigit()])
        kstring = n + ', ' + m
        kstrings.append(kstring)
    
    for kstring in kstrings:
        vals[kstring] = {'ground': {'p': [], 'r': [], 'f': []}, 'bcc': {'p': [], 'r': [], 'f': []}}
        
    for file in dirs:
#         print(file)
        if file == '.DS_Store':
            continue
        f = open(os.path.join(target, file), 'r')
        data = json.load(f)
        f.close()
        filez = file.split(':')
        n = ''.join([x for x in filez[2] if x.isdigit()])
        m = ''.join([x for x in filez[3] if x.isdigit()])
        kstring = n + ', ' + m
        
        print(kstring)
        data = clean(data)
        vals[kstring]['ground']['p'].append(data['ground']['p'])
        vals[kstring]['ground']['r'].append(data['ground']['r'])
        vals[kstring]['ground']['f'].append(data['ground']['f'])
        vals[kstring]['bcc']['p'].append(data['bcc']['p'])
        vals[kstring]['bcc']['r'].append(data['bcc']['r'])
        vals[kstring]['bcc']['f'].append(data['bcc']['f'])
    print(vals)
    return vals

# %%
vals = add_values()
# Out:
# 1000, 3
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.0008843062252410078
# Std Err: ground, f, 0.0017223417372867675
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 1000, 3
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.0014163847076271335
# Std Err: ground, f, 0.002701421044561546
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 1000, 3
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.008259935869000435
# Std Err: ground, f, 0.014843524041143329
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 1000, 3
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.05306623284406007
# Std Err: ground, f, 0.06507382028388989
# Std Err: bcc, p, 2.7755575615628914e-17
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 1000, 5
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.0013559973672540816
# Std Err: ground, f, 0.002603969746368034
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 1000, 5
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.0021469229702064303
# Std Err: ground, f, 0.003994282418657948
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 1000, 5
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.012106664972650396
# Std Err: ground, f, 0.020667753578945146
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 1000, 5
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.061792317158041586
# Std Err: ground, f, 0.0668561183173238
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 200, 10
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.0
# Std Err: ground, f, 0.0
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 200, 10
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.00043397124328692577
# Std Err: ground, f, 0.00048626953431199027
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 200, 10
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.0038124629755579265
# Std Err: ground, f, 0.003240440627445594
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 200, 10
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.035014887100489125
# Std Err: ground, f, 0.006098217149298637
# Std Err: bcc, p, 5.551115123125783e-17
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 200, 3
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.0009004303082415652
# Std Err: ground, f, 0.0017530615334322977
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 200, 3
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.0014416147335540104
# Std Err: ground, f, 0.0027476445002947527
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 200, 3
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.00836967915992005
# Std Err: ground, f, 0.015017383883353318
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 200, 3
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.05341681125226402
# Std Err: ground, f, 0.06522252425090583
# Std Err: bcc, p, 2.7755575615628914e-17
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 200, 5
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.0013659604167032076
# Std Err: ground, f, 0.002622391034914511
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 200, 5
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.002165140951531793
# Std Err: ground, f, 0.004025509488251144
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 200, 5
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.01219994389085458
# Std Err: ground, f, 0.02080088277117103
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 200, 5
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.06193669204389268
# Std Err: ground, f, 0.0668457456978378
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 500, 10
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.0018220708712890395
# Std Err: ground, f, 0.0034500510054200637
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 500, 10
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.002850349575052154
# Std Err: ground, f, 0.005175146736083915
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 500, 10
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.015563912213836214
# Std Err: ground, f, 0.02533901761039682
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 500, 10
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.06560496784131518
# Std Err: ground, f, 0.06482291756979164
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 500, 3
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.0008868965779616017
# Std Err: ground, f, 0.0017271787226572706
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 500, 3
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.001420450773522265
# Std Err: ground, f, 0.002708646765453185
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 500, 3
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.008282195719735196
# Std Err: ground, f, 0.014878318891595249
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 500, 3
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.05312743638987298
# Std Err: ground, f, 0.06507371405060572
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 500, 5
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.0013595276017793825
# Std Err: ground, f, 0.0026106426296986724
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 500, 5
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.0021487937406833627
# Std Err: ground, f, 0.003996981778792592
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 500, 5
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.012127176486717755
# Std Err: ground, f, 0.02069719034410226
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# 500, 5
# Std Err: ground, p, 0.0
# Std Err: ground, r, 0.061812954412808964
# Std Err: ground, f, 0.06683476046444695
# Std Err: bcc, p, 0.0
# Std Err: bcc, r, 0.0
# Std Err: bcc, f, 0.0
# {'1000, 3': {'ground': {'p': [1.0, 1.0, 1.0, 1.0], 'r': [0.0127, 0.0235, 0.0492, 0.2411], 'f': [0.0251, 0.046, 0.0933, 0.3774]}, 'bcc': {'p': [0.4307, 0.4307, 0.4307, 0.4307], 'r': [1.0, 1.0, 1.0, 1.0], 'f': [0.6021, 0.6021, 0.6021, 0.6021]}}, '1000, 5': {'ground': {'p': [1.0, 1.0, 1.0, 1.0], 'r': [0.0197, 0.0361, 0.0743, 0.3245], 'f': [0.0385, 0.0697, 0.1373, 0.4775]}, 'bcc': {'p': [0.5408, 0.5408, 0.5408, 0.5408], 'r': [1.0, 1.0, 1.0, 1.0], 'f': [0.702, 0.702, 0.702, 0.702]}}, '200, 10': {'ground': {'p': [0.0648, 0.0648, 0.0648, 0.0648], 'r': [0.0194, 0.0216, 0.0321, 0.143], 'f': [0.0299, 0.0323, 0.0424, 0.0851]}, 'bcc': {'p': [0.271, 0.617, 0.617, 0.8517], 'r': [1.0, 1.0, 1.0, 1.0], 'f': [0.4264, 0.7631, 0.7631, 0.9199]}}, '200, 3': {'ground': {'p': [1.0, 1.0, 1.0, 1.0], 'r': [0.0129, 0.0239, 0.0499, 0.244], 'f': [0.0255, 0.0467, 0.0946, 0.3811]}, 'bcc': {'p': [0.4345, 0.4345, 0.4345, 0.4346], 'r': [1.0, 1.0, 1.0, 1.0], 'f': [0.6057, 0.6058, 0.6058, 0.6059]}}, '200, 5': {'ground': {'p': [1.0, 1.0, 1.0, 1.0], 'r': [0.0198, 0.0365, 0.0749, 0.3261], 'f': [0.0388, 0.0703, 0.1383, 0.4794]}, 'bcc': {'p': [0.5429, 0.5429, 0.5429, 0.5429], 'r': [1.0, 1.0, 1.0, 1.0], 'f': [0.7038, 0.7038, 0.7038, 0.7038]}}, '500, 10': {'ground': {'p': [1.0, 1.0, 1.0, 1.0], 'r': [0.0266, 0.0487, 0.0984, 0.3906], 'f': [0.0518, 0.0927, 0.1777, 0.5495]}, 'bcc': {'p': [0.6163, 0.6163, 0.6163, 0.6163], 'r': [1.0, 1.0, 1.0, 1.0], 'f': [0.7626, 0.7626, 0.7626, 0.7626]}}, '500, 3': {'ground': {'p': [1.0, 1.0, 1.0, 1.0], 'r': [0.0128, 0.0236, 0.0493, 0.2418], 'f': [0.0252, 0.0461, 0.0936, 0.3783]}, 'bcc': {'p': [0.4316, 0.4316, 0.4316, 0.4316], 'r': [1.0, 1.0, 1.0, 1.0], 'f': [0.603, 0.603, 0.603, 0.603]}}, '500, 5': {'ground': {'p': [1.0, 1.0, 1.0, 1.0], 'r': [0.0197, 0.0362, 0.0744, 0.3249], 'f': [0.0386, 0.0699, 0.1376, 0.4781]}, 'bcc': {'p': [0.5413, 0.5413, 0.5413, 0.5413], 'r': [1.0, 1.0, 1.0, 1.0], 'f': [0.7024, 0.7024, 0.7024, 0.7024]}}}

# %%
# n_groups = 4
# fig, ax = plt.subplots(nrows=1, ncols=3)
# # plt.xlabel('Percentile')
# ax1, ax2, ax3 = ax.flatten()
# index = np.arange(n_groups)
# bar_width = 0.10
# opacity = 0.8
# ax1.set_ylabel('Precision')
# ax2.set_ylabel('Recall')
# ax3.set_ylabel('F1-Score')

# ax1.set_xlabel('Percentile')
# ax2.set_xlabel('Percentile')
# ax3.set_xlabel('Percentile')
# plt.ylim(0.0, 1.0)
# # print(type(ax1))

# plt.get_fignums()

# %%
for kind in ['ground', 'bcc']:
    
    n_groups = 4
    fig, ax = plt.subplots(nrows=1, ncols=3)
    
    # plt.xlabel('Percentile')
    ax1, ax2, ax3 = ax.flatten()
    index = np.arange(n_groups)
    bar_width = 0.10
    opacity = 0.8
    ax1.set_ylabel('Precision')
    ax2.set_ylabel('Recall')
    ax3.set_ylabel('F1-Score')

    ax1.set_xlabel('Percentile')
    ax2.set_xlabel('Percentile')
    ax3.set_xlabel('Percentile')
#     plt.ylim(0.0, 1.0)
    # print(type(ax1))

    plt.get_fignums()
    
    measures = ['p', 'r', 'f']
    axes = [ax1, ax2, ax3]
    tup = zip(axes, measures)
    for ax, measure in tup:
        print (type(ax))
        
        ax.set_ylim(0.0, 1.0)
        
        m200_3 = vals['200, 3'][kind][measure]
        print(f'''200, 3 {kind} {measure}''')
        print(vals['200, 3'][kind][measure])
        print('---------------')
        m200_5 = vals['200, 5'][kind][measure]
        print(f'''200, 5 {kind} {measure}''')
        print(vals['200, 5'][kind][measure])
        print('---------------')
        
        m200_10 = vals['200, 10'][kind][measure]
        print(f'''200, 10 {kind} {measure}''')
        print(vals['200, 10'][kind][measure])
        print('---------------')
        
        
        m500_3 = vals['500, 3'][kind][measure]
        print(f'''500, 3 {kind} {measure}''')
        print(vals['500, 3'][kind][measure])
        print('---------------')
        
        
        m500_5 = vals['500, 5'][kind][measure]
        print(f'''500, 5 {kind} {measure}''')
        print(vals['500, 5'][kind][measure])
        print('---------------')
        
        m500_10 = vals['500, 10'][kind][measure]
        print(f'''500, 10 {kind} {measure}''')
        print(vals['500, 10'][kind][measure])
        print('---------------')
        

        m1000_3 = vals['1000, 3'][kind][measure]
        print(f'''1000, 3 {kind} {measure}''')
        print(vals['1000, 3'][kind][measure])
        print('---------------')
        
        
        m1000_5 = vals['1000, 5'][kind][measure]
        print(f'''1000, 5 {kind} {measure}''')
        print(vals['1000, 5'][kind][measure])
        print('---------------')
        
        rects1 = ax.bar(index, m200_3, bar_width,
                         alpha=opacity,
                         color='darkgreen',
                         label='200, 3')
        rects2 = ax.bar(index + bar_width, m200_5, bar_width,
                         alpha=opacity,
                         color='forestgreen',
                         label='200, 5')
        rects3 = ax.bar(index + 2*bar_width, m200_10, bar_width,
                         alpha=opacity,
                         color='limegreen',
                         label='200, 10')
        rects4 = ax.bar(index + 3*bar_width, m500_3, bar_width,
                         alpha=opacity,
                         color='rosybrown',
                         label='500, 3')
        rects5 = ax.bar(index + 4*bar_width, m500_5, bar_width,
                         alpha=opacity,
                         color='lightcoral',
                         label='500, 5')
        rects6 = ax.bar(index + 5*bar_width, m500_10, bar_width,
                         alpha=opacity,
                         color='indianred',
                         label='500, 10')
        rects7 = ax.bar(index + 6*bar_width, m1000_3, bar_width,
                         alpha=opacity,
                         color='navy',
                         label='1000, 3')
        rects8 = ax.bar(index + 7*bar_width, m1000_5, bar_width,
                         alpha=opacity,
                         color='blue',
                         label='1000, 5')
        
        ax.set_xticks(index + 3*bar_width)
        ax.set_xticklabels([50, 80, 90, 98])
        
    handles, labels = ax.get_legend_handles_labels()
    box = ax.get_position()
    
    plt.tight_layout()
    plt.savefig(fname=kind + '2.png', format='png')
    plt.show()
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# 200, 3 ground p
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# 200, 5 ground p
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# 200, 10 ground p
# [0.0648, 0.0648, 0.0648, 0.0648]
# ---------------
# 500, 3 ground p
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# 500, 5 ground p
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# 500, 10 ground p
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# 1000, 3 ground p
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# 1000, 5 ground p
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# 200, 3 ground r
# [0.0129, 0.0239, 0.0499, 0.244]
# ---------------
# 200, 5 ground r
# [0.0198, 0.0365, 0.0749, 0.3261]
# ---------------
# 200, 10 ground r
# [0.0194, 0.0216, 0.0321, 0.143]
# ---------------
# 500, 3 ground r
# [0.0128, 0.0236, 0.0493, 0.2418]
# ---------------
# 500, 5 ground r
# [0.0197, 0.0362, 0.0744, 0.3249]
# ---------------
# 500, 10 ground r
# [0.0266, 0.0487, 0.0984, 0.3906]
# ---------------
# 1000, 3 ground r
# [0.0127, 0.0235, 0.0492, 0.2411]
# ---------------
# 1000, 5 ground r
# [0.0197, 0.0361, 0.0743, 0.3245]
# ---------------
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# 200, 3 ground f
# [0.0255, 0.0467, 0.0946, 0.3811]
# ---------------
# 200, 5 ground f
# [0.0388, 0.0703, 0.1383, 0.4794]
# ---------------
# 200, 10 ground f
# [0.0299, 0.0323, 0.0424, 0.0851]
# ---------------
# 500, 3 ground f
# [0.0252, 0.0461, 0.0936, 0.3783]
# ---------------
# 500, 5 ground f
# [0.0386, 0.0699, 0.1376, 0.4781]
# ---------------
# 500, 10 ground f
# [0.0518, 0.0927, 0.1777, 0.5495]
# ---------------
# 1000, 3 ground f
# [0.0251, 0.046, 0.0933, 0.3774]
# ---------------
# 1000, 5 ground f
# [0.0385, 0.0697, 0.1373, 0.4775]
# ---------------
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# 200, 3 bcc p
# [0.4345, 0.4345, 0.4345, 0.4346]
# ---------------
# 200, 5 bcc p
# [0.5429, 0.5429, 0.5429, 0.5429]
# ---------------
# 200, 10 bcc p
# [0.271, 0.617, 0.617, 0.8517]
# ---------------
# 500, 3 bcc p
# [0.4316, 0.4316, 0.4316, 0.4316]
# ---------------
# 500, 5 bcc p
# [0.5413, 0.5413, 0.5413, 0.5413]
# ---------------
# 500, 10 bcc p
# [0.6163, 0.6163, 0.6163, 0.6163]
# ---------------
# 1000, 3 bcc p
# [0.4307, 0.4307, 0.4307, 0.4307]
# ---------------
# 1000, 5 bcc p
# [0.5408, 0.5408, 0.5408, 0.5408]
# ---------------
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# 200, 3 bcc r
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# 200, 5 bcc r
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# 200, 10 bcc r
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# 500, 3 bcc r
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# 500, 5 bcc r
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# 500, 10 bcc r
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# 1000, 3 bcc r
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# 1000, 5 bcc r
# [1.0, 1.0, 1.0, 1.0]
# ---------------
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# 200, 3 bcc f
# [0.6057, 0.6058, 0.6058, 0.6059]
# ---------------
# 200, 5 bcc f
# [0.7038, 0.7038, 0.7038, 0.7038]
# ---------------
# 200, 10 bcc f
# [0.4264, 0.7631, 0.7631, 0.9199]
# ---------------
# 500, 3 bcc f
# [0.603, 0.603, 0.603, 0.603]
# ---------------
# 500, 5 bcc f
# [0.7024, 0.7024, 0.7024, 0.7024]
# ---------------
# 500, 10 bcc f
# [0.7626, 0.7626, 0.7626, 0.7626]
# ---------------
# 1000, 3 bcc f
# [0.6021, 0.6021, 0.6021, 0.6021]
# ---------------
# 1000, 5 bcc f
# [0.702, 0.702, 0.702, 0.702]
# ---------------

# %%
# tup = zip(axes, measure)

# %%
# for ax, meas in tup:
#     print (ax, meas)

# %%
plt.get_fignums()
# Out:
# []
